# %% [markdown]
# # Cinema LSTM

# %% [markdown]
# ----

# %% [markdown]
# Starting from Panda and Numpy

# %%
# pandas as pd
try:
    import pandas as pd
    print('Pandas already installed, only imported')
except:
    # !pip install pandas
    import pandas as pd
    print('Pandas was not installed, installed and imported')
    
# numpy as np
try:
    import numpy as np
    print('NumPy already installed, only imported')
except:
    # !pip install numpy
    import numpy as np
    print('NumPy was not installed, installed and imported')
    
# pyplot as plt
try:
    import matplotlib.pyplot as plt
    print('PyPlot already installed, only imported')
except:
    # !pip install matplotlib
    import matplotlib.pyplot as plt
    print('PyPlot was not installed, installed and imported')
# Out:
# Pandas already installed, only imported
# NumPy already installed, only imported
# PyPlot already installed, only imported

# %%
cinema = pd.read_csv('../data/cinema.csv', sep=';', low_memory=False)

# Mapping dictionary for translating Dutch day names to English
dutch_to_english = {
    'Zondag': 'Sunday',
    'maandag': 'Monday',
    'dinsdag': 'Tuesday',
    'woensdag': 'Wednesday',
    'donderdag': 'Thursday',
    'vrijdag': 'Friday',
    'zaterdag': 'Saturday'
}

# Translate Dutch day names to English
cinema['Day'] = cinema['Day'].map(dutch_to_english)

# Convert the "Date" column to datetime
cinema['Date'] = pd.to_datetime(cinema['Date'], format='%d/%m/%Y')

# Drop rows with missing values in the "Visitor" column
cinema = cinema.dropna(subset=['Visitor'])

# Convert the "Visitor" column to numeric to check for non-numeric values
cinema['Visitor'] = pd.to_numeric(cinema['Visitor'], errors='coerce')

# Drop rows with non-numeric values in the "Visitor" column
cinema = cinema.dropna(subset=['Visitor'])

# Convert the "Visitor" column to integer
cinema['Visitor'] = cinema['Visitor'].astype(int)

# Extract each column into separate variables
day_categorical = cinema['Day'].astype('category')
date = cinema['Date']
visitor = cinema['Visitor']

# %%
cinema.head()
# Out:
#          Day       Date  Visitor
# 0     Sunday 2023-01-01      484
# 1     Monday 2023-01-02      832
# 2    Tuesday 2023-01-03      872
# 3  Wednesday 2023-01-04     1003
# 4   Thursday 2023-01-05      851

# %%
cinema.dtypes
# Out:
# Day                object
# Date       datetime64[ns]
# Visitor             int32
# dtype: object

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# Summary statistics for visitor counts
visitor_summary = cinema['Visitor'].describe()

# Print the summary statistics
print(visitor_summary)
# Out:
# count     428.000000
# mean      497.616822
# std       269.279597
# min       107.000000
# 25%       304.500000
# 50%       406.500000
# 75%       653.750000
# max      1437.000000
# Name: Visitor, dtype: float64

# %%
cinema.head()
# Out:
#          Day       Date  Visitor
# 0     Sunday 2023-01-01      484
# 1     Monday 2023-01-02      832
# 2    Tuesday 2023-01-03      872
# 3  Wednesday 2023-01-04     1003
# 4   Thursday 2023-01-05      851

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# Feature scaling
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(cinema['Visitor'].values.reshape(-1, 1))

# Prepare data for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Define sequence length
seq_length = 7

# Create sequences for LSTM input
X, y = create_sequences(scaled_data, seq_length)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Define LSTM model architecture
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(seq_length, 1)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
loss = model.evaluate(X_test, y_test, verbose=0)
print(f"LSTM Model Test Loss: {loss}")

# Make predictions
predictions = model.predict(X_test)

# Inverse scale the predictions
predictions = scaler.inverse_transform(predictions)

# Inverse scale the actual values for plotting
actual_values = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs. predicted visitor numbers
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))

train_length = len(y_train_actual)

plt.figure(figsize=(12, 6))
plt.plot(range(train_length), y_train_actual, label='Actual (Training)')

plt.plot(range(train_length, train_length+len(actual_values)), actual_values, label='Actual (Testing)')
plt.plot(range(train_length, train_length+len(predictions)), predictions, label='Predicted (Testing)')

plt.title('Actual vs. Predicted Visitors')
plt.xlabel('Time')
plt.ylabel('Number of Visitors')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 3s 43ms/step - loss: 0.0668 - val_loss: 0.1399
# Epoch 2/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0310 - val_loss: 0.0567
# Epoch 3/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0231 - val_loss: 0.0650
# Epoch 4/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0219 - val_loss: 0.0674
# Epoch 5/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0211 - val_loss: 0.0607
# Epoch 6/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0209 - val_loss: 0.0595
# Epoch 7/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0203 - val_loss: 0.0568
# Epoch 8/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0198 - val_loss: 0.0574
# Epoch 9/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0194 - val_loss: 0.0542
# Epoch 10/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0189 - val_loss: 0.0524
# Epoch 11/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0187 - val_loss: 0.0541
# Epoch 12/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0185 - val_loss: 0.0514
# Epoch 13/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0181 - val_loss: 0.0492
# Epoch 14/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0180 - val_loss: 0.0513
# Epoch 15/100
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0173 - val_loss: 0.0473
# Epoch 16/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0171 - val_loss: 0.0466
# Epoch 17/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0172 - val_loss: 0.0443
# Epoch 18/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0490
# Epoch 19/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0161 - val_loss: 0.0426
# Epoch 20/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0412
# Epoch 21/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0404
# Epoch 22/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0387
# Epoch 23/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0149 - val_loss: 0.0367
# Epoch 24/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0364
# Epoch 25/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0353
# Epoch 26/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0147 - val_loss: 0.0369
# Epoch 27/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0367
# Epoch 28/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0136 - val_loss: 0.0318
# Epoch 29/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0132 - val_loss: 0.0313
# Epoch 30/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0129 - val_loss: 0.0313
# Epoch 31/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0345
# Epoch 32/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0131 - val_loss: 0.0319
# Epoch 33/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0308
# Epoch 34/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0132 - val_loss: 0.0284
# Epoch 35/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0128 - val_loss: 0.0283
# Epoch 36/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0273
# Epoch 37/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0124 - val_loss: 0.0279
# Epoch 38/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 0.0292
# Epoch 39/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0123 - val_loss: 0.0372
# Epoch 40/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0127 - val_loss: 0.0307
# Epoch 41/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0261
# Epoch 42/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0119 - val_loss: 0.0264
# Epoch 43/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0115 - val_loss: 0.0286
# Epoch 44/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0281
# Epoch 45/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0253
# Epoch 46/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0112 - val_loss: 0.0250
# Epoch 47/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0121 - val_loss: 0.0247
# Epoch 48/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0127 - val_loss: 0.0267
# Epoch 49/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0122 - val_loss: 0.0245
# Epoch 50/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0288
# Epoch 51/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0253
# Epoch 52/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0252
# Epoch 53/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0239
# Epoch 54/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0242
# Epoch 55/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0241
# Epoch 56/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0236
# Epoch 57/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.0246
# Epoch 58/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.0273
# Epoch 59/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0105 - val_loss: 0.0238
# Epoch 60/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0250
# Epoch 61/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0257
# Epoch 62/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0251
# Epoch 63/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0243
# Epoch 64/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0268
# Epoch 65/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0103 - val_loss: 0.0249
# Epoch 66/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0101 - val_loss: 0.0270
# Epoch 67/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0243
# Epoch 68/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0311
# Epoch 69/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0106 - val_loss: 0.0269
# Epoch 70/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0103 - val_loss: 0.0267
# Epoch 71/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0106 - val_loss: 0.0242
# Epoch 72/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0101 - val_loss: 0.0242
# Epoch 73/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0253
# Epoch 74/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0248
# Epoch 75/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0250
# Epoch 76/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0257
# Epoch 77/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0263
# Epoch 78/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - val_loss: 0.0260
# Epoch 79/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0274
# Epoch 80/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0259
# Epoch 81/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0266
# Epoch 82/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0332
# Epoch 83/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0114 - val_loss: 0.0247
# Epoch 84/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0329
# Epoch 85/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0107 - val_loss: 0.0238
# Epoch 86/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0248
# Epoch 87/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0094 - val_loss: 0.0257
# Epoch 88/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0273
# Epoch 89/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0092 - val_loss: 0.0288
# Epoch 90/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0107 - val_loss: 0.0329
# Epoch 91/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0248
# Epoch 92/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0267
# Epoch 93/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0259
# Epoch 94/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0268
# Epoch 95/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0259
# Epoch 96/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0273
# Epoch 97/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0260
# Epoch 98/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0261
# Epoch 99/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0096 - val_loss: 0.0252
# Epoch 100/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0095 - val_loss: 0.0253
# LSTM Model Test Loss: 0.025312868878245354
# 3/3 [==============================] - 0s 8ms/step

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Assuming 'actual_values' and 'predictions' are your actual and predicted values
# Evaluate the model using Mean Squared Error (MSE)
mse = mean_squared_error(actual_values, predictions)
print(f"Mean Squared Error (MSE): {mse}")

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate additional metrics for the 'Visitors' value
actual_values = np.array(actual_values)
predictions = np.array(predictions)

# Minimum value
min_value = np.min(actual_values)
print(f"Minimum value: {min_value}")

# Maximum value
max_value = np.max(actual_values)
print(f"Maximum value: {max_value}")

# Range
range_value = max_value - min_value
print(f"Range: {range_value}")

# Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((actual_values - predictions) / actual_values)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")
# Calculate R-squared (coefficient of determination)
r2 = r2_score(actual_values, predictions)
print(f"R-squared (Coefficient of Determination): {r2}")
# Out:
# Mean Squared Error (MSE): 44775.937470697056
# Root Mean Squared Error (RMSE): 211.603254867918
# Minimum value: 267.0
# Maximum value: 1437.0
# Range: 1170.0
# Mean Absolute Percentage Error (MAPE): 22.771629349898408%
# R-squared (Coefficient of Determination): 0.5451331919669975

# %% [markdown]
# Import the data:

# %%
wifi_data = pd.read_csv("../data/wifi_data.csv", low_memory=False)

# %%
wifi_data.head()
# Out:
#                       Date Time  Date Time(RAW) Total Online Devices  \
# 0  1-9-2023 00:00:00 - 01:00:00     45169.95833                 61 #
# 1  1-9-2023 01:00:00 - 02:00:00     45170.00000                 58 #
# 2  1-9-2023 02:00:00 - 03:00:00     45170.04167                 57 #
# 3  1-9-2023 03:00:00 - 04:00:00     45170.08333                 57 #
# 4  1-9-2023 04:00:00 - 05:00:00     45170.12500                 57 #
#
#    Total Online Devices(RAW) Speed Bad  Speed Bad(RAW) Speed Good  \
# 0                    60.9000    0,57 #          0.5667     9,88 #
# 1                    58.3500    0,85 #          0.8500       11 #
# 2                    57.3833    0,47 #          0.4667     9,73 #
# 3                    57.4000    0,52 #          0.5167       10 #
# 4                    57.1333    0,30 #          0.3000       10 #
#
#    Speed Good(RAW) Speed Better  Speed Better(RAW)  ... Experience Bad  \
# 0           9.8833         50 #            50.4500  ...         0,62 #
# 1          10.7833         47 #            46.7167  ...         0,55 #
# 2           9.7333         47 #            47.1833  ...         0,38 #
# 3          10.4000         46 #            46.4833  ...         0,15 #
# 4          10.4833         46 #            46.3500  ...         0,42 #
#
#    Experience Bad(RAW) Experience Good  Experience Good(RAW)  \
# 0               0.6167          0,17 #                0.1667
# 1               0.5500          0,15 #                0.1500
# 2               0.3833          0,17 #                0.1667
# 3               0.1500             0 #                0.0000
# 4               0.4167          0,17 #                0.1667
#
#   Experience Better  Experience Better(RAW) Downtime  Downtime(RAW) Coverage  \
# 0              62 #                 62.3667       0%            0.0     100%
# 1              58 #                 58.4500       0%            0.0     100%
# 2              57 #                 56.8333       0%            0.0     100%
# 3              57 #                 57.3667       0%            0.0     100%
# 4              57 #                 56.9667       0%            0.0     100%
#
#    Coverage(RAW)
# 0        10000.0
# 1        10000.0
# 2        10000.0
# 3        10000.0
# 4        10000.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Use only the necessary columns from our dataset:

# %%
wifi_data = wifi_data[['Date Time', 'Total Online Devices']]
wifi_data.head()
# Out:
#                       Date Time Total Online Devices
# 0  1-9-2023 00:00:00 - 01:00:00                 61 #
# 1  1-9-2023 01:00:00 - 02:00:00                 58 #
# 2  1-9-2023 02:00:00 - 03:00:00                 57 #
# 3  1-9-2023 03:00:00 - 04:00:00                 57 #
# 4  1-9-2023 04:00:00 - 05:00:00                 57 #

# %% [markdown]
# Ok, now let's check if there's any missing values

# %%
wifi_data.isnull().sum()
# Out:
# Date Time                0
# Total Online Devices    52
# dtype: int64

# %% [markdown]
# Drop the null values from the dataset:

# %%
wifi_data = wifi_data.dropna()
wifi_data.isna().sum()
# Out:
# Date Time               0
# Total Online Devices    0
# dtype: int64

# %% [markdown]
# Convert the value of the total number of the devices to an integer:

# %%
wifi_data['Total Online Devices'] = wifi_data['Total Online Devices'].str.replace('#','').astype(int)

# %% [markdown]
# Have a look of the chnaged data and check their data type:

# %%
wifi_data.head()
# Out:
#                       Date Time  Total Online Devices
# 0  1-9-2023 00:00:00 - 01:00:00                    61
# 1  1-9-2023 01:00:00 - 02:00:00                    58
# 2  1-9-2023 02:00:00 - 03:00:00                    57
# 3  1-9-2023 03:00:00 - 04:00:00                    57
# 4  1-9-2023 04:00:00 - 05:00:00                    57

# %% [markdown]
# Group all the all data based on the date. Add the total, mean, max and min of the devices conneted on a specific date:

# %%
dt = wifi_data['Date Time'].str.split(' ').str[0] 
devices = wifi_data['Total Online Devices']

new_data_wifi_df = pd.DataFrame({'datetime': dt, 'totaldevices': devices})

new_data_wifi_df = new_data_wifi_df[new_data_wifi_df['datetime'] != 'Averages']

new_data_wifi_df['datetime'] = pd.to_datetime(new_data_wifi_df['datetime'], format='%d-%m-%Y')

grouped_data = new_data_wifi_df.groupby('datetime').agg({'totaldevices': ['mean', 'max', 'min']})
grouped_data.columns = grouped_data.columns.map(''.join)

total_devices_sum = new_data_wifi_df.groupby('datetime')['totaldevices'].sum()

sorted_grouped_wifi_data = pd.merge(grouped_data, total_devices_sum, left_index=True, right_index=True)

sorted_grouped_wifi_data.rename(columns={'totaldevices': 'totaldevicessum'}, inplace=True)

sorted_grouped_wifi_data = sorted_grouped_wifi_data.sort_index()

sorted_grouped_wifi_data.head()
# Out:
#             totaldevicesmean  totaldevicesmax  totaldevicesmin  \
# datetime
# 2023-09-01        104.125000              195               57
# 2023-09-02         63.625000               72               57
# 2023-09-03         62.833333               72               58
# 2023-09-04        162.583333              387               57
# 2023-09-05        162.583333              377               52
#
#             totaldevicessum
# datetime
# 2023-09-01             2499
# 2023-09-02             1527
# 2023-09-03             1508
# 2023-09-04             3902
# 2023-09-05             3902

# %%
wifi = sorted_grouped_wifi_data.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# Feature scaling
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(wifi['totaldevicessum'].values.reshape(-1, 1))

# Prepare data for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(X), np.array(y)

# Define sequence length
seq_length = 7

# Create sequences for LSTM input
X, y = create_sequences(scaled_data, seq_length)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Define LSTM model architecture
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(seq_length, 1)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
loss = model.evaluate(X_test, y_test, verbose=0)
print(f"LSTM Model Test Loss: {loss}")

# Make predictions
predictions = model.predict(X_test)

# Inverse scale the predictions
predictions = scaler.inverse_transform(predictions)

# Inverse scale the actual values for plotting
actual_values = scaler.inverse_transform(y_test.reshape(-1, 1))

# Plot actual vs. predicted visitor numbers
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))

train_length = len(y_train_actual)

plt.figure(figsize=(12, 6))
plt.plot(range(train_length), y_train_actual, label='Actual (Training)')

plt.plot(range(train_length, train_length+len(actual_values)), actual_values, label='Actual (Testing)')
plt.plot(range(train_length, train_length+len(predictions)), predictions, label='Predicted (Testing)')

plt.title('Actual vs. Predicted Visitors')
plt.xlabel('Time')
plt.ylabel('Total Devices Sum')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 141ms/step - loss: 0.2873 - val_loss: 0.2506
# Epoch 2/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2157 - val_loss: 0.1794
# Epoch 3/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1478 - val_loss: 0.1043
# Epoch 4/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0749 - val_loss: 0.0514
# Epoch 5/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0588 - val_loss: 0.0629
# Epoch 6/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0686 - val_loss: 0.0503
# Epoch 7/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0531 - val_loss: 0.0522
# Epoch 8/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0562 - val_loss: 0.0577
# Epoch 9/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0566 - val_loss: 0.0534
# Epoch 10/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0538 - val_loss: 0.0491
# Epoch 11/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0521 - val_loss: 0.0484
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0521 - val_loss: 0.0483
# Epoch 13/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0517 - val_loss: 0.0489
# Epoch 14/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0513 - val_loss: 0.0483
# Epoch 15/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0512 - val_loss: 0.0478
# Epoch 16/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0509 - val_loss: 0.0474
# Epoch 17/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0508 - val_loss: 0.0473
# Epoch 18/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0506 - val_loss: 0.0468
# Epoch 19/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0501 - val_loss: 0.0466
# Epoch 20/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0498 - val_loss: 0.0467
# Epoch 21/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0497 - val_loss: 0.0460
# Epoch 22/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0494 - val_loss: 0.0448
# Epoch 23/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0490 - val_loss: 0.0444
# Epoch 24/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0485 - val_loss: 0.0463
# Epoch 25/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0493 - val_loss: 0.0455
# Epoch 26/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0479 - val_loss: 0.0434
# Epoch 27/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0468 - val_loss: 0.0421
# Epoch 28/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0466 - val_loss: 0.0414
# Epoch 29/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0463 - val_loss: 0.0415
# Epoch 30/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0455 - val_loss: 0.0432
# Epoch 31/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0458 - val_loss: 0.0396
# Epoch 32/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0444 - val_loss: 0.0392
# Epoch 33/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0446 - val_loss: 0.0414
# Epoch 34/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0437 - val_loss: 0.0376
# Epoch 35/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0435 - val_loss: 0.0362
# Epoch 36/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0431 - val_loss: 0.0365
# Epoch 37/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0412 - val_loss: 0.0371
# Epoch 38/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0410 - val_loss: 0.0346
# Epoch 39/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0399 - val_loss: 0.0333
# Epoch 40/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0393 - val_loss: 0.0348
# Epoch 41/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0391 - val_loss: 0.0308
# Epoch 42/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0374 - val_loss: 0.0316
# Epoch 43/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0370 - val_loss: 0.0289
# Epoch 44/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0360 - val_loss: 0.0290
# Epoch 45/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0352 - val_loss: 0.0276
# Epoch 46/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0345 - val_loss: 0.0261
# Epoch 47/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0338 - val_loss: 0.0246
# Epoch 48/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0331 - val_loss: 0.0242
# Epoch 49/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0325 - val_loss: 0.0257
# Epoch 50/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0321 - val_loss: 0.0217
# Epoch 51/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0315 - val_loss: 0.0211
# Epoch 52/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0306 - val_loss: 0.0220
# Epoch 53/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0302 - val_loss: 0.0187
# Epoch 54/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0317 - val_loss: 0.0209
# Epoch 55/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0290 - val_loss: 0.0185
# Epoch 56/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0292 - val_loss: 0.0205
# Epoch 57/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0286 - val_loss: 0.0166
# Epoch 58/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0280 - val_loss: 0.0150
# Epoch 59/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0294 - val_loss: 0.0235
# Epoch 60/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0300 - val_loss: 0.0157
# Epoch 61/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0287 - val_loss: 0.0165
# Epoch 62/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0266 - val_loss: 0.0166
# Epoch 63/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0267 - val_loss: 0.0147
# Epoch 64/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0266 - val_loss: 0.0138
# Epoch 65/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0267 - val_loss: 0.0197
# Epoch 66/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0269 - val_loss: 0.0122
# Epoch 67/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0286 - val_loss: 0.0187
# Epoch 68/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0273 - val_loss: 0.0132
# Epoch 69/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0263 - val_loss: 0.0124
# Epoch 70/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0264 - val_loss: 0.0159
# Epoch 71/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0257 - val_loss: 0.0123
# Epoch 72/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0260 - val_loss: 0.0142
# Epoch 73/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0256 - val_loss: 0.0124
# Epoch 74/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0256 - val_loss: 0.0125
# Epoch 75/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0251 - val_loss: 0.0127
# Epoch 76/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0256 - val_loss: 0.0136
# Epoch 77/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0264 - val_loss: 0.0139
# Epoch 78/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0260 - val_loss: 0.0127
# Epoch 79/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0259 - val_loss: 0.0131
# Epoch 80/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0250 - val_loss: 0.0141
# Epoch 81/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0259 - val_loss: 0.0091
# Epoch 82/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0262 - val_loss: 0.0155
# Epoch 83/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0255 - val_loss: 0.0096
# Epoch 84/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0283 - val_loss: 0.0151
# Epoch 85/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0251 - val_loss: 0.0118
# Epoch 86/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0245 - val_loss: 0.0109
# Epoch 87/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.0122
# Epoch 88/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0245 - val_loss: 0.0135
# Epoch 89/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.0102
# Epoch 90/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0249 - val_loss: 0.0134
# Epoch 91/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0243 - val_loss: 0.0114
# Epoch 92/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0241 - val_loss: 0.0109
# Epoch 93/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0249 - val_loss: 0.0113
# Epoch 94/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0243 - val_loss: 0.0098
# Epoch 95/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0241 - val_loss: 0.0166
# Epoch 96/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0255 - val_loss: 0.0097
# Epoch 97/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0254 - val_loss: 0.0192
# Epoch 98/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0349 - val_loss: 0.0158
# Epoch 99/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0301 - val_loss: 0.0111
# Epoch 100/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0309 - val_loss: 0.0226
# LSTM Model Test Loss: 0.022631725296378136
# 2/2 [==============================] - 0s 13ms/step

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Assuming 'actual_values' and 'predictions' are your actual and predicted values
# Evaluate the model using Mean Squared Error (MSE)
mse = mean_squared_error(actual_values, predictions)
print(f"Mean Squared Error (MSE): {mse}")

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate additional metrics for the 'Visitors' value
actual_values = np.array(actual_values)
predictions = np.array(predictions)

# Minimum value
min_value = np.min(actual_values)
print(f"Minimum value: {min_value}")

# Maximum value
max_value = np.max(actual_values)
print(f"Maximum value: {max_value}")

# Range
range_value = max_value - min_value
print(f"Range: {range_value}")

# Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((actual_values - predictions) / actual_values)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape}%")

# Calculate R-squared (coefficient of determination)
r2 = r2_score(actual_values, predictions)
print(f"R-squared (Coefficient of Determination): {r2}")
